# %%
# !unzip CDZ.zip
# Out:
# Archive:  CDZ.zip
#    creating: CDZ - Copy/
#   inflating: CDZ - Copy/CDZ.md
#    creating: CDZ - Copy/data/
#    creating: CDZ - Copy/data/encoders/
#    creating: CDZ - Copy/data/spectrograms/
#    creating: CDZ - Copy/FSDD_recordings/
#   inflating: CDZ - Copy/FSDD_recordings/0_george_0.wav
#   inflating: CDZ - Copy/FSDD_recordings/0_george_1.wav
#   inflating: CDZ - Copy/FSDD_recordings/0_george_10.wav
#   inflating: CDZ - Copy/FSDD_recordings/0_george_11.wav
#   inflating: CDZ - Copy/FSDD_recordings/0_george_12.wav
#   inflating: CDZ - Copy/FSDD_recordings/0_george_13.wav
#   inflating: CDZ - Copy/FSDD_recordings/0_george_14.wav
#   inflating: CDZ - Copy/FSDD_recordings/0_george_15.wav
#   inflating: CDZ - Copy/FSDD_recordings/0_george_16.wav
#   inflating: CDZ - Copy/FSDD_recordings/0_george_17.wav
#   inflating: CDZ - Copy/FSDD_recordings/0_george_18.wav
#   inflating: CDZ - Copy/FSDD_recordings/0_george_19.wav
#   inflating: CDZ - Copy/FSDD_recordings/0_george_2.wav
# ...

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/CDZ
# Out:
# /content/CDZ

# %%
# !pwd
# Out:
# /content/CDZ

# %%
# !pip install -r /content/CDZ/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.5/647.5 kB 15.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for annoy: filename=annoy-1.17.3-cp312-cp312-linux_x86_64.whl size=549274 sha256=78e586d3d4bb2fef21f8207b206e5b8418c6b162f26d973e4b0cb1b3942398b2
#   Stored in directory: /root/.cache/pip/wheels/db/b9/53/a3b2d1fe1743abadddec6aa541294b24fdbc39d7800bc57311
# Successfully built annoy
# ...

# %%
# !touch /content/cdz

# %%
# !python /content/CDZ/scripts/preprocess_fsdd.py
# Out:
# Starting FSDD spectrogram preprocessing...
# Found 3000 .wav files. Starting spectrogram generation...
# Generating Spectrograms: 100% 3000/3000 [01:30<00:00, 33.26it/s]
# FSDD spectrogram preprocessing finished.

# %%
# !python /content/CDZ/scripts/preprocess_mnist.py
# Out:
# Starting MNIST dataset download...
# ...
# 100% 9.91M/9.91M [00:00<00:00, 20.6MB/s]
# 100% 28.9k/28.9k [00:00<00:00, 485kB/s]
# 100% 1.65M/1.65M [00:00<00:00, 4.63MB/s]
# 100% 4.54k/4.54k [00:00<00:00, 19.6MB/s]
# MNIST dataset downloaded successfully.
# MNIST dataset download finished.

# %%
# !python /content/CDZ/scripts/train_autoencoders.py
# Out:
# Using device: cuda
#
# Training Autoencoder for FSDD...
# Epoch [1/100], Loss: 0.1171
# Epoch [2/100], Loss: 0.0567
# Epoch [3/100], Loss: 0.0439
# Epoch [4/100], Loss: 0.0381
# Epoch [5/100], Loss: 0.0351
# Epoch [6/100], Loss: 0.0333
# Epoch [7/100], Loss: 0.0321
# Epoch [8/100], Loss: 0.0314
# Epoch [9/100], Loss: 0.0307
# Epoch [10/100], Loss: 0.0302
# Epoch [11/100], Loss: 0.0296
# Epoch [12/100], Loss: 0.0293
# Epoch [13/100], Loss: 0.0289
# Epoch [14/100], Loss: 0.0287
# Epoch [15/100], Loss: 0.0285
# Epoch [16/100], Loss: 0.0283
# Epoch [17/100], Loss: 0.0281
# Epoch [18/100], Loss: 0.0279
# Epoch [19/100], Loss: 0.0278
# Epoch [20/100], Loss: 0.0277
# Epoch [21/100], Loss: 0.0276
# Epoch [22/100], Loss: 0.0274
# Epoch [23/100], Loss: 0.0274
# Epoch [24/100], Loss: 0.0273
# Epoch [25/100], Loss: 0.0271
# Epoch [26/100], Loss: 0.0270
# Epoch [27/100], Loss: 0.0270
# Epoch [28/100], Loss: 0.0269
# Epoch [29/100], Loss: 0.0268
# Epoch [30/100], Loss: 0.0267
# ...

# %%
# !python /content/CDZ/scripts/run_brain.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Cleaning up node: audio_node_3075
# Timesteps:  85% 2289/2700 [00:23<00:03, 103.58it/s]Splitting node visual_node_3906 due to low variance...
# Cleaning up node: visual_node_3906
# Splitting node audio_node_3076 due to low variance...
# Cleaning up node: audio_node_3076
# Timesteps:  88% 2389/2700 [00:24<00:02, 106.95it/s]Splitting node visual_node_3907 due to low variance...
# Cleaning up node: visual_node_3907
# Splitting node audio_node_2406 due to low variance...
# Created audio_node_3077
# Cleaning up node: audio_node_2406
# Cleaning up cluster: visual_cluster_1405
# Timesteps:  92% 2492/2700 [00:25<00:01, 107.28it/s]Splitting node visual_node_3909 due to low variance...
# Cleaning up node: visual_node_3909
# Splitting node audio_node_3077 due to low variance...
# Cleaning up node: audio_node_3077
# Timesteps:  96% 2598/2700 [00:26<00:00, 108.86it/s]Splitting node visual_node_556 due to low variance...
# ...

# %%
# !python /content/CDZ/scripts/visualize_tsne.py
# Out:
# Loading pre-trained encoders...
# Loading datasets...
# Generating encodings for MNIST:   3% 31/938 [00:02<01:03, 14.32it/s]
# Running t-SNE for 'MNIST_Train' on 2000 samples...
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 2000 samples in 0.001s...
# [t-SNE] Computed neighbors for 2000 samples in 0.312s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2000
# [t-SNE] Computed conditional probabilities for sample 2000 / 2000
# [t-SNE] Mean sigma: 1.595129
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 69.479591
# [t-SNE] KL divergence after 300 iterations: 1.504677
# Plotting results for 'MNIST_Train'...
# Plot saved to visualizations/MNIST_Train_tsne.png
# Generating encodings for MNIST:  20% 31/157 [00:00<00:02, 53.78it/s]
# Running t-SNE for 'MNIST_Test' on 2000 samples...
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 2000 samples in 0.000s...
# [t-SNE] Computed neighbors for 2000 samples in 0.087s...
# ...

# %%
# !python /content/CDZ/scripts/evaluate_encodings.py
# Out:
# Loading pre-trained encoders for supervised evaluation...
# Loading datasets for supervised evaluation...
#
# --- Evaluating MNIST Encodings ---
# Generating encodings for MNIST: 100% 469/469 [00:17<00:00, 27.22it/s]
# Generating encodings for MNIST: 100% 79/79 [00:02<00:00, 29.24it/s]
# Training MLP classifier...
# Iteration 1, loss = 0.62367364
# Iteration 2, loss = 0.19380613
# Iteration 3, loss = 0.14897048
# Iteration 4, loss = 0.12321802
# Iteration 5, loss = 0.10515350
# Iteration 6, loss = 0.09235685
# Iteration 7, loss = 0.08233814
# Iteration 8, loss = 0.07467456
# Iteration 9, loss = 0.06831354
# Iteration 10, loss = 0.06314395
# Iteration 11, loss = 0.05852249
# Iteration 12, loss = 0.05470519
# Iteration 13, loss = 0.05164221
# Iteration 14, loss = 0.04853786
# Iteration 15, loss = 0.04577819
# Iteration 16, loss = 0.04364584
# Iteration 17, loss = 0.04147987
# Iteration 18, loss = 0.03957902
# Iteration 19, loss = 0.03781520
# Iteration 20, loss = 0.03610224
# ...
